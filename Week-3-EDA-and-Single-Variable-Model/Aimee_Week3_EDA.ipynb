# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("/Users/aimeexu/Desktop/dataset.csv")
print("Data Successfully Imported")
# Out:
# Data Successfully Imported

# %%
data.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  \
# 0  1503960366      4/12/16       13162           8.50
# 1  1503960366      4/13/16       10735           6.97
# 2  1503960366      4/14/16       10460           6.74
# 3  1503960366      4/15/16        9762           6.28
# 4  1503960366      4/16/16       12669           8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# ...

# %%
data.tail() #starting from 0, ending at 893
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  \
# 889  8877689391       5/8/16       10686       8.110000
# 890  8877689391       5/9/16       20226      18.250000
# 891  8877689391      5/10/16       10733       8.150000
# 892  8877689391      5/11/16       21420      19.559999
# 893  8877689391      5/12/16        8064       6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 889                       0.0                1.08                      0.20
# 890                       0.0               11.10                      0.80
# 891                       0.0                1.35                      0.46
# 892                       0.0               13.22                      0.41
# 893                       0.0                1.82                      0.04
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 889                 6.80                     0.00                 17
# ...

# %%
data.shape #894 rows, 14 columns
# Out:
# (894, 14)

# %%
data.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Id                           33
# ActivityDate                 31
# TotalSteps                  842
# TotalDistance               615
# LoggedActivitiesDistance     19
# VeryActiveDistance          333
# ModeratelyActiveDistance    211
# LightActiveDistance         491
# SedentaryActiveDistance       9
# VeryActiveMinutes           122
# FairlyActiveMinutes          81
# LightlyActiveMinutes        335
# SedentaryMinutes            548
# Calories                    726
# dtype: int64

# %%
data.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  LoggedActivitiesDistance  \
# count  8.940000e+02    894.000000     894.000000                894.000000
# mean   4.782378e+09   8030.912752       5.772170                  0.113737
# std    2.434238e+09   4904.332852       3.816237                  0.635163
# min    1.503960e+09      0.000000       0.000000                  0.000000
# 25%    2.320127e+09   4505.250000       3.085000                  0.000000
# 50%    4.445115e+09   7818.500000       5.440000                  0.000000
# 75%    6.962181e+09  10977.500000       7.800000                  0.000000
# max    8.877689e+09  36019.000000      28.030001                  4.942142
#
#        VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# count          894.000000                894.000000           894.000000
# mean             1.580000                  0.596745             3.512718
# ...

# %%
data['ActivityDate'].unique()
# Out:
# array(['4/12/16', '4/13/16', '4/14/16', '4/15/16', '4/16/16', '4/17/16',
#        '4/18/16', '4/19/16', '4/20/16', '4/21/16', '4/22/16', '4/23/16',
#        '4/24/16', '4/25/16', '4/26/16', '4/27/16', '4/28/16', '4/29/16',
#        '4/30/16', '5/1/16', '5/2/16', '5/3/16', '5/4/16', '5/5/16',
#        '5/6/16', '5/7/16', '5/8/16', '5/9/16', '5/10/16', '5/11/16',
#        '5/12/16'], dtype=object)

# %%
data['SedentaryActiveDistance'].unique()
# Out:
# array([0.  , 0.01, 0.02, 0.03, 0.05, 0.07, 0.04, 0.11, 0.1 ])

# %%
data['LoggedActivitiesDistance'].unique()
# Out:
# array([0.        , 1.95959604, 4.08169222, 2.78517509, 3.16782188,
#        4.86978292, 4.85130692, 3.28541493, 4.9305501 , 4.94214201,
#        4.92484093, 4.86179209, 4.88560486, 4.91114616, 2.83232594,
#        4.91236782, 4.878232  , 2.25308108, 2.09214711])

# %%
# PART 2: RECLEANING THE DATA

# %%
data.isnull().sum() # don't have to worry about dropping columns, replacing w/ columns
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
#3 RELATIONSHIP ANALYSIS

# %%
correlation = data.corr() # no errors

# %%
sns.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, annot=True)

# %%
sns.pairplot(data) # only want to see correlation w/ specific pairs

# %%
sns.relplot(x = 'VeryActiveMinutes', y = 'VeryActiveDistance', hue = 'Id',  data = data)

# %%
sns.relplot(x = 'FairlyActiveMinutes', y = 'ModeratelyActiveDistance', hue = 'Id',  data = data)

# %%
newdata = data.drop(['SedentaryActiveDistance','LoggedActivitiesDistance'],axis=1)

# %%
newdata.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  VeryActiveDistance  \
# 0  1503960366      4/12/16       13162           8.50                1.88
# 1  1503960366      4/13/16       10735           6.97                1.57
# 2  1503960366      4/14/16       10460           6.74                2.44
# 3  1503960366      4/15/16        9762           6.28                2.14
# 4  1503960366      4/16/16       12669           8.16                2.71
#
#    ModeratelyActiveDistance  LightActiveDistance  VeryActiveMinutes  \
# 0                      0.55                 6.06                 25
# 1                      0.69                 4.71                 21
# 2                      0.40                 3.91                 30
# 3                      1.26                 2.83                 29
# 4                      0.41                 5.04                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# ...

# %%
correlat = newdata.corr()
sns.heatmap(correlat, xticklabels = correlat.columns, yticklabels = correlat.columns, annot=True)

# %%
sns.relplot(x = 'LightlyActiveMinutes', y = 'LightActiveDistance', hue = 'Id',  data = data)

# %%
sns.distplot(newdata['LightActiveDistance'])

# %%
sns.distplot(newdata['LightlyActiveMinutes'])

# %%
sns.distplot(newdata['ModeratelyActiveDistance'])

# %%
sns.distplot(newdata['FairlyActiveMinutes'])

# %%
sns.distplot(newdata['VeryActiveDistance'])

# %%
sns.distplot(newdata['VeryActiveMinutes'])

# %%
sns.distplot(newdata['SedentaryMinutes'])

# %%
sns.distplot(data['SedentaryActiveDistance'])
# Out:
# /Users/aimeexu/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x ='FairlyActiveMinutes', kind = 'box', data = newdata)

# %%
sns.catplot(x ='ModeratelyActiveDistance', kind = 'box', data = newdata)

# %%
sns.catplot(x ='TotalSteps', kind = 'box', data = data)

# %%
sns.catplot(x ='TotalDistance', kind = 'box', data = data)

# %%
sns.catplot(x ='VeryActiveDistance', kind = 'box', data = data)

# %%
sns.catplot(x ='VeryActiveMinutes', kind = 'box', data = data)

# %%
sns.catplot(x ='LightActiveDistance', kind = 'box', data = data)

# %%
newdata.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  VeryActiveDistance  \
# count  8.940000e+02    894.000000     894.000000          894.000000
# mean   4.782378e+09   8030.912752       5.772170            1.580000
# std    2.434238e+09   4904.332852       3.816237            2.704044
# min    1.503960e+09      0.000000       0.000000            0.000000
# 25%    2.320127e+09   4505.250000       3.085000            0.000000
# 50%    4.445115e+09   7818.500000       5.440000            0.340000
# 75%    6.962181e+09  10977.500000       7.800000            2.197500
# max    8.877689e+09  36019.000000      28.030001           21.920000
#
#        ModeratelyActiveDistance  LightActiveDistance  VeryActiveMinutes  \
# count                894.000000           894.000000         894.000000
# mean                   0.596745             3.512718          22.253915
# std                    0.896373             1.942749          33.317996
# ...
